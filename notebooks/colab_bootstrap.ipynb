# %% [markdown]
# <a href="https://colab.research.google.com/github/YuraKucher/rag-engine/blob/main/colab_bootstrap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Bootstrap — RAG Engine
#
# Цей ноутбук:
# - підключає Google Drive
# - клонує GitHub-репозиторій
# - встановлює залежності
# - готує PYTHONPATH
# - перевіряє, що проєкт працює
#
# Запускається **один раз на сесію**.
# У всіх інших ноутбуках використовується через `%run`.

# %%
def is_colab():
    try:
        import google.colab
        return True
    except ImportError:
        return False

assert is_colab(), "❌ This notebook must be run in Google Colab"

print("✅ Running in Google Colab")
# Out:
# ✅ Running in Google Colab

# %%
from google.colab import drive

DRIVE_PATH = "/content/drive"

drive.mount(DRIVE_PATH)

print("✅ Google Drive mounted at", DRIVE_PATH)
# Out:
# Mounted at /content/drive
# ✅ Google Drive mounted at /content/drive

# %%
from pathlib import Path

# 🔧 ЗМІНИ ТУТ, ЯКЩО ПОТРІБНО
GITHUB_REPO_URL = "https://github.com/YuraKucher/rag-engine.git"
PROJECT_NAME = "rag-engine"

CONTENT_ROOT = Path("/content")
PROJECT_ROOT = CONTENT_ROOT / PROJECT_NAME
DRIVE_ROOT = Path("/content/drive/MyDrive")

print("Project root:", PROJECT_ROOT)
print("Drive root:", DRIVE_ROOT)
# Out:
# Project root: /content/rag-engine
# Drive root: /content/drive/MyDrive

# %%
import subprocess

if not PROJECT_ROOT.exists():
    print("📥 Cloning repository...")
    subprocess.run(
        ["git", "clone", GITHUB_REPO_URL],
        check=True
    )
else:
    print("✅ Repository already exists")

print("📁 Repo contents:")
# !ls -l {PROJECT_ROOT}
# Out:
# 📥 Cloning repository...
# 📁 Repo contents:
# total 40
# -rw-r--r--  1 root root 9906 Jan  6 21:24 ARCHITECTURE.md
# drwxr-xr-x  2 root root 4096 Jan  6 21:24 config
# drwxr-xr-x 13 root root 4096 Jan  6 21:24 core
# -rw-r--r--  1 root root    0 Jan  6 21:24 README.md
# -rw-r--r--  1 root root  363 Jan  6 21:24 requirements.txt
# drwxr-xr-x  2 root root 4096 Jan  6 21:24 schemas
# drwxr-xr-x  2 root root 4096 Jan  6 21:24 services
# drwxr-xr-x  2 root root 4096 Jan  6 21:24 tests
# drwxr-xr-x  3 root root 4096 Jan  6 21:24 ui

# %%
# %cd /content/rag-engine
# Out:
# /content/rag-engine

# %%
import os

req_file = PROJECT_ROOT / "requirements.txt"

assert req_file.exists(), "❌ requirements.txt not found"

print("📦 Installing dependencies...")
# !pip install --upgrade pip
# !pip install -r requirements.txt

print("✅ Dependencies installed")
# Out:
# 📦 Installing dependencies...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 126.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 128.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 111.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 107.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.7 MB/s  0:00:00
# ...

# %%
import sys

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("✅ Project added to PYTHONPATH")
print(PROJECT_ROOT in map(Path, sys.path))
# Out:
# ✅ Project added to PYTHONPATH
# True

# %%
RAG_DATA_ROOT = DRIVE_ROOT / "rag-data"

DIRS = {
    "documents": RAG_DATA_ROOT / "documents",
    "chunks": RAG_DATA_ROOT / "chunks",
    "indexes": RAG_DATA_ROOT / "indexes",
    "feedback": RAG_DATA_ROOT / "feedback",
    "evaluations": RAG_DATA_ROOT / "evaluations",
    "state": RAG_DATA_ROOT / "state",
}

for name, path in DIRS.items():
    path.mkdir(parents=True, exist_ok=True)
    print(f"✅ {name}: {path}")
# Out:
# ✅ documents: /content/drive/MyDrive/rag-data/documents
# ✅ chunks: /content/drive/MyDrive/rag-data/chunks
# ✅ indexes: /content/drive/MyDrive/rag-data/indexes
# ✅ feedback: /content/drive/MyDrive/rag-data/feedback
# ✅ evaluations: /content/drive/MyDrive/rag-data/evaluations
# ✅ state: /content/drive/MyDrive/rag-data/state

# %%
expected_dirs = [
    "config",
    "core",
    "schemas",
    "services",
    "ui",
    "tests",
]

missing = [d for d in expected_dirs if not (PROJECT_ROOT / d).exists()]

if missing:
    raise RuntimeError(f"❌ Missing directories: {missing}")

print("✅ Project structure OK")
# Out:
# ✅ Project structure OK

# %%
try:
    from config import settings
    from services.rag_service import RAGService
    from core.indexing.embedder import Embedder
    from core.retrieval.retriever import Retriever

    print("✅ Core imports successful")
except Exception as e:
    print("❌ Import error")
    raise e
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# ✅ Core imports successful

# %%
import platform
import torch

print("Python:", platform.python_version())
print("OS:", platform.system())
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Python: 3.12.12
# OS: Linux
# Torch: 2.9.0+cpu
# CUDA available: False
